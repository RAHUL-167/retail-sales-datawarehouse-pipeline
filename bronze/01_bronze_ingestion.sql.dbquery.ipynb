-- %%
USE CATALOG retail_sales_catalog;
USE SCHEMA bronze;

DROP TABLE IF EXISTS bronze.customers_raw;
CREATE TABLE bronze.customers_raw
USING CSV
OPTIONS (
  path 's3://retail-dwh-capstone-project/raw/customers/',
  header 'true',
  inferSchema 'true'
);

DROP TABLE IF EXISTS bronze.products_raw;
CREATE TABLE bronze.products_raw
USING CSV
OPTIONS (
  path 's3://retail-dwh-capstone-project/raw/products/',
  header 'true',
  inferSchema 'true'
);

DROP TABLE IF EXISTS bronze.stores_raw;
CREATE TABLE bronze.stores_raw
USING CSV
OPTIONS (
  path 's3://retail-dwh-capstone-project/raw/stores/',
  header 'true',
  inferSchema 'true'
);

DROP TABLE IF EXISTS bronze.sales_raw;
CREATE TABLE bronze.sales_raw
USING CSV
OPTIONS (
  path 's3://retail-dwh-capstone-project/raw/sales/',
  header 'true',
  inferSchema 'true'
);
